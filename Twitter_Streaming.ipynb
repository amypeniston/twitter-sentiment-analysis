# %% [markdown]
# # Streaming Tweets into Database

# %%
import mysql.connector
from mysql.connector import Error
import tweepy
from textblob import TextBlob
import credentials

# %%
TRACK_WORDS = ['covid19']
TABLE_NAME = "covid19"
TABLE_ATTRIBUTES = "id_str VARCHAR(255), created_at DATETIME, text VARCHAR(1000), \
            polarity DECIMAL(5,4), subjectivity DECIMAL(5,4), user_created_at VARCHAR(255), user_id_str VARCHAR(255), user_screen_name VARCHAR(255), user_location VARCHAR(255), \
            user_description VARCHAR(255), user_followers_count INT, longitude DOUBLE, latitude DOUBLE, \
            retweet_count INT, favorite_count INT"

# %%
try:
    connection = mysql.connector.connect(host=credentials.HOST,
                                         database=credentials.DATABASE,
                                         user=credentials.USER,
                                         password=credentials.PASSWORD)
    if connection.is_connected():
        cursor = connection.cursor()
        cursor.execute("""SELECT COUNT(*) FROM information_schema.tables WHERE table_name= '{0}'""".format(TABLE_NAME))
        if cursor.fetchone()[0] != 1:
            cursor.execute("CREATE TABLE {} ({})".format(TABLE_NAME, TABLE_ATTRIBUTES))
            connection.commit()
        cursor.close()
        
except Error as e:
    print("Error connecting:", e)
# finally:
#     if (connection.is_connected()):
#         cursor.close()
#         connection.close()
#         print("Connection closed")

# %%
def deEmojify(text):
    if text:
        return text.encode('ascii', 'ignore').decode('ascii')
    else:
        return None

# %%
# Override tweepy's default StreamLister to add logic to on_status and on_error
class CustomStreamListener(tweepy.StreamListener):
    
    def on_status(self, status):
        '''Extract tweet (aka status) content.'''
        if (status.retweeted) or ('RT @' in status.text):
            return True
        id_str = status.id_str
        created_at = status.created_at
        try:
            text = deEmojify(status.extended_tweet["full_text"])
        except AttributeError:
            text = deEmojify(status.text)
        sentiment = TextBlob(text).sentiment
        polarity = sentiment.polarity
        subjectivity = sentiment.subjectivity
        
        user_created_at = status.user.created_at
        user_location = deEmojify(status.user.location)
        user_description = deEmojify(status.user.description)
        user_followers_count = status.user.followers_count
        user_id_str = status.user.id_str
        user = api.get_user(user_id_str)
        user_screen_name = user.screen_name
        
        latitude = None
        longitude = None
        if status.coordinates:
            longitude = status.coordinates["coordinates"][0]
            latitude = status.coordinates["coordinates"][1]
    
        retweet_count = status.retweet_count
        favorite_count = status.favorite_count
        
        print("\nUSER ", user_id_str, user_screen_name)
        print("Tweet length: ", len(text))
        print("Polarity: ", polarity)
        print("Subjectivity: ", subjectivity)
        print("Tweet content: ", status.text)
        print("Lat: {}, Long: {}".format(latitude, longitude))
        
        if connection.is_connected():
            cursor = connection.cursor()
            sql = """INSERT INTO {} (id_str,created_at,text,polarity,
                subjectivity, user_created_at, user_id_str, user_screen_name, user_location,
                user_description, user_followers_count, longitude,
                latitude, retweet_count, favorite_count) VALUES
                (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s)""".format(TABLE_NAME)
            values = (id_str, created_at, text, polarity, subjectivity,
                user_created_at, user_id_str, user_screen_name, user_location, user_description,
                user_followers_count, longitude, latitude, retweet_count, favorite_count)
            cursor.execute(sql, values)
            connection.commit()
            cursor.close()
        else:
            print("Not connected to database")
            return False
    
    def on_error(self, status_code):
        '''Handle rate limiting.'''
        if status_code == 420:
            # Disconnect
            return False

# %%
auth = tweepy.OAuthHandler(credentials.API_KEY, credentials.API_SECRET_KEY)
auth.set_access_token(credentials.ACCESS_TOKEN, credentials.ACCESS_TOKEN_SECRET)
api = tweepy.API(auth)

# %% [markdown]
# Access a tweet by ID:
#
# https://twitter.com/ShaliniAlok/status/1246499367202066432

# %% [markdown]
# * Subjectivity: float [0.0, 1.0] - where 0.0 is very objective and 1.0 is very subjective
# * Polarity: float [-1.0, 1.0] - where -1.0 is very negative and 1.0 is very positive

# %%
customStreamListener = CustomStreamListener()
stream = tweepy.Stream(auth=api.auth, listener=customStreamListener)
stream.filter(languages=["en"], track=TRACK_WORDS)
connection.close()
# Out:
# USER  3031934368 MarissaEsque
# Tweet length:  256
# Polarity:  0.19357142857142856
# Subjectivity:  0.4992857142857143
# Tweet content:  In a virtual meeting with @SenSchumer, his staff, and a bunch of other progressive advocates right now, talking abo… https://t.co/FnJI0jvh1g
# Lat: None, Long: None
#
# USER  867755682556248064 FemicideWatch
# Tweet length:  281
# Polarity:  0.0
# Subjectivity:  0.1
# Tweet content:  Following our awareness on the impacts of #VAWG&amp;COVID19: In Mexico, since the quarantine was announced, calls to de… https://t.co/7Tw5RaAUN0
# Lat: None, Long: None
#
# USER  101244025 aogulmus
# Tweet length:  235
# Polarity:  0.69
# Subjectivity:  0.95
# Tweet content:  We as humans haven’t been very kind to this earth. Pollution, deforestation, slaughtering animals... This is kind o… https://t.co/oSx8IQjexe
# Lat: None, Long: None
#
# USER  315429133 vjacqueline66
# Tweet length:  150
# Polarity:  -0.16666666666666666
# Subjectivity:  0.43333333333333335
# Tweet content:  Oh oh he is triggers the #maga people people - he mentioned a black person #msnbc #WorstPresidentInHistory #maga my… https://t.co/WXqOTk8ibM
# Lat: None, Long: None
#
# USER  757704444 Ray_Honeycutt
# Tweet length:  179
# Polarity:  -0.08333333333333333
# Subjectivity:  0.18888888888888888
# Tweet content:  "If the recent pattern holds and claims continue to be similarly-dire, we are about two weeks away from erasing all… https://t.co/SfEcMjXahn
# Lat: None, Long: None
#
# USER  1023980414904541184 KellyRasti
# Tweet length:  115
# Polarity:  0.4375
# Subjectivity:  0.6125
# Tweet content:  Neat idea if you’re able to participate! And if you can’t fast or don’t want to, you can still donate to… https://t.co/xeZDSLvAcd
# Lat: None, Long: None
#
# USER  1230689032977428481 11Lalulu
# Tweet length:  101
# Polarity:  0.0
# Subjectivity:  0.0
# Tweet content:  Co worker #COVID19,#Paterson,#Quarantine,#StaffingVissionaries,#QuedateEnCasa https://t.co/29MhiFWpwB
# Lat: None, Long: None
#
# USER  89772606 screamBRIx3
# Tweet length:  57
# Polarity:  0.0
# Subjectivity:  0.1
# Tweet content:  Told niggas this is gonna be in the winter starting five.
# Lat: None, Long: None
#
# USER  1240479895693807616 GrBlanc
# Tweet length:  262
# Polarity:  0.04545454545454545
# Subjectivity:  0.48484848484848486
# Tweet content:  WHAT IF New York CITY tax $$ went back to the workers? “PAUSE” on business extended until May = A necessary RENT FR… https://t.co/7UzXqxu2I7
# Lat: None, Long: None
#
# USER  1963092902 MF_360
# Tweet length:  64
# Polarity:  -0.1
# Subjectivity:  0.55
# Tweet content:  Sad, but worth reading... https://t.co/0B4TdimCnB #FDNY #COVID19
# Lat: None, Long: None
#
# USER  807642 johnbollwitt
# Tweet length:  188
# Polarity:  0.10714285714285714
# Subjectivity:  0.37142857142857144
# Tweet content:  Gloves nor masks make you invincible. They can help, but you need to be smart about what you are doing while wearin… https://t.co/JorHv4Qwiy
# Lat: None, Long: None
#
# USER  4913320595 Only_rock_radio
# Tweet length:  193
# Polarity:  0.4
# Subjectivity:  0.5
# Tweet content:  enjoy our friends Corner Table Remake by Paleosonik @paleosonik On https://t.co/tmYHgdAL43 #SocialDistancing… https://t.co/YcTLeTmW3Z
# Lat: None, Long: None
#
# USER  4913320595 Only_rock_radio
# Tweet length:  214
# Polarity:  0.8
# Subjectivity:  0.75
# Tweet content:  #StayAtHomeAndStaySafe #SocialDistancing #CoronaLockdown #Coronavirus #COVID19 Great unsigned music Sovtek Baby by… https://t.co/ICwjiSScMf
# Lat: None, Long: None
#
# USER  394980082 jfizzle913
# Tweet length:  81
# Polarity:  0.0
# Subjectivity:  0.0
# Tweet content:  He needs to be on medication! He is NUTTS! #PressConference #covid19 #coronavirus
# Lat: None, Long: None
#
# USER  224831688 SisyphusScot
# Tweet length:  98
# Polarity:  0.0
# Subjectivity:  1.0
# Tweet content:  “The nuclear button has to be looked after!” says utter twat on @BBCNewsnight #COVID19 #BorisJohnson
# Lat: None, Long: None
#
# USER  49849883 Mike_McGinley
# Tweet length:  193
# Polarity:  -0.3979166666666667
# Subjectivity:  0.5354166666666667
# Tweet content:  It’s so rude the way the media is talked to at these. You’re a “third grade reporter” and saying “you will never ma… https://t.co/gJAp2IH8As
# Lat: None, Long: None
#
# USER  1239676876014202892 BTrader420
# Tweet length:  253
# Polarity:  0.0
# Subjectivity:  0.5
# Tweet content:  #India has allowed the export of #Hydroxychloroquine to the United States, making an exception to its earlier ban o… https://t.co/wyIBXKpNAV
# Lat: None, Long: None
#
# USER  1200847059374313477 HHINTONU
# Tweet length:  315
# Polarity:  0.0
# Subjectivity:  0.125
# Tweet content:  @mrkellyknight @UOPX Same accreditation: #ButlerUniversity #IndianaUniversity #ASU #DePaul #astate #ballstate… https://t.co/JJorySJBJa
# Lat: None, Long: None
#
# USER  872257951255285760 LexieSlain
# Tweet length:  275
# Polarity:  0.0
# Subjectivity:  0.0
# Tweet content:  Venmo is lexieremi1106
# https://t.co/7B9eWb83Hb I appreciate anything, I still need a lot of help before I can pay a… https://t.co/zXDHAvG0B1
# Lat: None, Long: None
#
# USER  28114643 BCP72
# Tweet length:  87
# Polarity:  0.0
# Subjectivity:  0.0
# Tweet content:  This mofo... #WhiteHouseBriefing #COVID19 #DonaldTrump #GOP #MAGA #LiarInChief #IMPOTUS
# Lat: None, Long: None
#
# USER  358279270 tiger_girl2000
# Tweet length:  228
# Polarity:  -0.29341827876984133
# Subjectivity:  0.48095238095238096
# Tweet content:  @TomFitton @realDonaldTrump No, he’s not SMART enough to be a dictator: Trump is, instead, a FAILURE whose incompet… https://t.co/Hif43YypTI
# Lat: None, Long: None
#
# USER  10335502 Nuckman
# Tweet length:  123
# Polarity:  0.3666666666666667
# Subjectivity:  0.8333333333333334
# Tweet content:  Nice shoutout from @realDonaldTrump and Dr Fauci from the press conference today. Keep making Nebraska as safe as p… https://t.co/Regp3TLp09
# Lat: None, Long: None
#
# USER  2174637904 alexe42261051
# Tweet length:  184
# Polarity:  0.0
# Subjectivity:  0.0
# Tweet content:  @HouseNGR @NGRPresident @NGRSenate @DailyPostNGR @DailyTimesNGR @cbngov_akin1 @cenbank #Nigerians #SMEs Nigeria gov… https://t.co/YBUswTNu7M
# Lat: None, Long: None
#
# USER  38506577 tsparks611
# Tweet length:  114
# Polarity:  0.0
# Subjectivity:  0.0
# Tweet content:  @SusanLetournea6 @realDonaldTrump Maybe not according to you, but it is according to him...https://t.co/mRwqmmDJqZ
# Lat: None, Long: None
#
# USER  35291387 Ghastly_Grinner
# Tweet length:  196
# Polarity:  -0.039999999999999994
# Subjectivity:  0.45999999999999996
# Tweet content:  Of all the things that I thought would kick off the end of the world the red Chinese eating weird shit was not at t… https://t.co/AKlUqmT2Mc
# Lat: None, Long: None
#
# USER  3342807545 Kalukaluemmanu2
# Tweet length:  9
# Polarity:  -0.5
# Subjectivity:  1.0
# Tweet content:  Fake News
# Lat: None, Long: None
#
# USER  20784326 AZLTAnews
# Tweet length:  240
# Polarity:  0.5416666666666666
# Subjectivity:  0.4388888888888889
# Tweet content:  Thank you @BreakthruBevAZ and @YoungsMarket_Co for helping keep #Arizona’s public safety officers safe! Great to se… https://t.co/1uQ04tKZAD
# Lat: None, Long: None
#
# USER  235471733 DanaAnneLea
# Tweet length:  237
# Polarity:  0.13636363636363635
# Subjectivity:  0.45454545454545453
# Tweet content:  LSSNCA @CompassionVann is working around the clock to provide emergency assistance to newly arrived refugees and im… https://t.co/CxtS5bKSHd
# Lat: None, Long: None
#
# USER  961782651584688128 BrownEyedWarden
# Tweet length:  41
# Polarity:  0.0
# Subjectivity:  0.0
# Tweet content:  Although, I stopped tuning in a week ago.
# Lat: None, Long: None
#
# USER  951103304 awruddiman
# Tweet length:  277
# Polarity:  0.0018518518518518452
# Subjectivity:  0.362962962962963
# Tweet content:  ⬇️ We in the interior of British Columbia can take some gentle reassurance from this that our collective efforts of… https://t.co/ql20jWwC5M
# Lat: None, Long: None
#
# USER  152805513 yamkin1
# Tweet length:  239
# Polarity:  0.11666666666666668
# Subjectivity:  0.6666666666666666
# Tweet content:  Update @23:38 UTC: Coronavirus Confirmed Cases and Deaths by Country, Territory, or Conveyance Subject To Change:… https://t.co/sQTjTTfoNk
# Lat: None, Long: None
#
# USER  1191651381729472512 PacoRodrib
# Tweet length:  230
# Polarity:  0.22000000000000003
# Subjectivity:  0.38
# Tweet content:  This is the direct consequence of accepting that the virus will spread widely in society. Well, maybe drastic actio… https://t.co/N3zmYGFWPv
# Lat: None, Long: None
#
# USER  1244733180927709188 Wigglyworm8
# Tweet length:  279
# Polarity:  0.2714285714285714
# Subjectivity:  0.401360544217687
# Tweet content:  If you have Covid or symptoms of it however mild they may be initially pls take it seriously. Rest up, sleep, drink… https://t.co/ziMaAsaEgN
# Lat: None, Long: None
#
# USER  212716225 Nobody_special1
# Tweet length:  155
# Polarity:  -0.062499999999999986
# Subjectivity:  0.5166666666666666
# Tweet content:  Could the #USA be any more incompetent on the #COVID19 response?
#
# Asking for the whole fucking world.… https://t.co/pvxKyieVhd
# Lat: None, Long: None
#
# USER  885891622919184384 Billius27
# Tweet length:  289
# Polarity:  0.10727272727272727
# Subjectivity:  0.2709090909090909
# Tweet content:  📈NEW: Death trajectories adjusted for population.
# The initial boost stage has passed, it's time to see how nations… https://t.co/TBkUe0dqo6
# Lat: None, Long: None
#
# USER  16853632 ViewNaija
# Tweet length:  111
# Polarity:  0.0
# Subjectivity:  0.0
# Tweet content:  COVID-19: Stimulus Package Distribution Turns Rowdy In Lagos - https://t.co/Qfavt1gDeI #COVID19 #COVID19Nigeria
# Lat: None, Long: None
#
# USER  1219291033227399168 DisquietComms
# Tweet length:  282
# Polarity:  -0.5
# Subjectivity:  0.8333333333333334
# Tweet content:  #COVID19 is showing the world how the public/private sphere divide is always meaningless when it comes to #VAWG - i… https://t.co/rIhkOuvSyO
# Lat: None, Long: None
#
# USER  59481164 zeelz
# Tweet length:  102
# Polarity:  0.0
# Subjectivity:  0.5
# Tweet content:  . @GovWike Your Excellency Sir, should we still go ahead to open the markets tomorrow? #COVID19Nigeria
# Lat: None, Long: None
#
# USER  84305810 PaulTheDesigner
# Tweet length:  264
# Polarity:  -0.015000000000000003
# Subjectivity:  0.29500000000000004
# Tweet content:  During this lockdown I’ve seen art, creativity, communication, love and caring levels go through the roof. It’s goi… https://t.co/VGMxrSeV2x
# Lat: None, Long: None
#
# USER  620480641 JairoWashington
# Tweet length:  160
# Polarity:  0.25
# Subjectivity:  0.3333333333333333
# Tweet content:  Hudson, NY with the first responders and healthcare workers. They are headed to the hospital to cheer everyone up 👏… https://t.co/S3ct5TkKZw
# Lat: None, Long: None
#
# USER  87741755 TheGod_Particle
# Tweet length:  94
# Polarity:  0.10000000000000002
# Subjectivity:  0.3833333333333333
# Tweet content:  If you were clear about  #COVID19 testing WHY would you have to be on the phone all the time ?
# Lat: None, Long: None
#
# USER  1059215710042374148 SuomiROCKSWOT
# Tweet length:  107
# Polarity:  0.25
# Subjectivity:  0.375
# Tweet content:  Is Covid19 the greatest intelligence-failure of recent American history?
#
# ..of recent history of the world?
# Lat: None, Long: None
#
# USER  2907292888 johnnyadelawad
# Tweet length:  127
# Polarity:  0.0
# Subjectivity:  0.0
# Tweet content:  If a man expects a woman to be an angel in his life , He must create haven for her .
# Angels don’t leave in hell.… https://t.co/Oc7J1lyVgo
# Lat: None, Long: None
#
# USER  49338156 phidippides26
# Tweet length:  31
# Polarity:  0.375
# Subjectivity:  0.575
# Tweet content:  This is so thoughtful and cool.
# Lat: None, Long: None
#
# USER  20819456 GetsGreased
# Tweet length:  184
# Polarity:  -0.20000000000000004
# Subjectivity:  0.35555555555555557
# Tweet content:  Italy's advisor to health Minister said last week they were counting anyone dead in hospitals where someone with… https://t.co/NFHq9H0NdE
# Lat: None, Long: None
#
# USER  1587196260 KellyBot5000
# Tweet length:  109
# Polarity:  -0.3
# Subjectivity:  0.4
# Tweet content:  @Ugarles Update: he was tested for influenza a and b, both were negative. Doctor says he probably has COVID19
# Lat: None, Long: None
#
# USER  1221304909288443904 maahhsseee
# Tweet length:  182
# Polarity:  -0.7142857142857143
# Subjectivity:  0.8571428571428571
# Tweet content:  Please stay at home. cover you mouths when sneezing and coughing. My father is a bus driver...i do not want this to… https://t.co/EvLequ3hBh
# Lat: None, Long: None
#
# USER  776431061429526528 ShekaMoi
# Tweet length:  185
# Polarity:  0.0
# Subjectivity:  0.0
# Tweet content:  This #WorldHealthDay will all @g20org states step up funding to help @WHO to protect the world’s poorest against… https://t.co/MPTYDo2zEb
# Lat: None, Long: None
#
# USER  1071980596736520193 nobertteretto
# Tweet length:  172
# Polarity:  -0.03333333333333336
# Subjectivity:  0.6666666666666666
# Tweet content:  Man this self quarantine crap would be so much easier with a mansion and millions of dollars... so, famous people,… https://t.co/ZbqlLQ4hDo
# Lat: None, Long: None
#
# USER  1193274313744486400 LisRyan_Nutri
# Tweet length:  94
# Polarity:  0.8
# Subjectivity:  0.75
# Tweet content:  Great write up by @MarieMFinnegan in today's @IrishTimes on the #ECB and the #Covid_19 crisis.
# Lat: None, Long: None
#
# USER  425405449 EPTXFire
# Tweet length:  134
# Polarity:  0.13636363636363635
# Subjectivity:  0.5
# Tweet content:  LIVE: City Officials Provide COVID-19 Update
#
# Watch: https://t.co/nrWXeC2Bfv
#
# #COVID19 #CORONAVIRUS #IAMELPASO https://t.co/nRXEfieFhb
# Lat: None, Long: None
#
# USER  1247258068875972613 l_slough
# Tweet length:  32
# Polarity:  0.0
# Subjectivity:  0.0
# Tweet content:  @neil_slough have you seen this?
# Lat: None, Long: None
#
# USER  1235367745539248128 covid_19bot
# Tweet length:  205
# Polarity:  0.4
# Subjectivity:  1.0
# Tweet content:  Coronavirus Update
# Country_Region: Niger
# Confirmed: 184 =&gt; 253
# Deaths: 10 =&gt; 10
# Recovered: 13 =&gt; 26
# The data comes… https://t.co/uDcwfnx72G
# Lat: None, Long: None
#
# USER  560111522 sproutiepout
# Tweet length:  264
# Polarity:  0.0
# Subjectivity:  0.0
# Tweet content:  And...the Obama Admin is invoked again for why something occurring now is not up to par.
# #COVIDー19  #COVID19… https://t.co/F8MbtqCNUX
# Lat: None, Long: None
#
# USER  197927845 garthmullins
# Tweet length:  276
# Polarity:  -0.06666666666666667
# Subjectivity:  0.6166666666666667
# Tweet content:  @JohnDivney @GBMC73 Totally agree. You just gotta start. We began with no funding, no location, no mission statemen… https://t.co/XtxUeau7ir
# Lat: None, Long: None
#
# USER  714934318305517568 FixUSANow
# Tweet length:  233
# Polarity:  0.18452380952380953
# Subjectivity:  0.6226190476190476
# Tweet content:  @JoyceWhiteVance The more a certain group of people scream that #Hydroxychloroquine should not be given to patients… https://t.co/E8Ke15Ks7x
# Lat: None, Long: None
#
# USER  2879985791 LollysMum1
# Tweet length:  291
# Polarity:  0.07333333333333333
# Subjectivity:  0.5933333333333334
# Tweet content:  @scotmacscotbot MSM is acting as #DeflectionCentral keeping us busy &amp; allowing #UKGOV to get away #HerdImmunity aga… https://t.co/WtMcjmWMaQ
# Lat: None, Long: None
#
# USER  34241428 RichValdes
# Tweet length:  77
# Polarity:  0.13636363636363635
# Subjectivity:  0.5
# Tweet content:  Listen LIVE now: @RudyGiuliani on the @marklevinshow 🎧 https://t.co/FYSMpAwShH
# Lat: None, Long: None
#
# USER  1160658646180728834 Razz_4_Speaker
# Tweet length:  156
# Polarity:  0.0
# Subjectivity:  0.0
# Tweet content:  @Milmore @Greg19711 @DineshDSouza @FoxNews I think it's CNN &amp; MSNBC that are refusing to cover the daily briefings… https://t.co/GNmuTKiO2Q
# Lat: None, Long: None
#
# USER  317290922 Parker_Rush
# Tweet length:  308
# Polarity:  0.06742424242424241
# Subjectivity:  0.23333333333333334
# Tweet content:  @MSNBC
# WHY ARE YOU BROADCASTING TRUMP LIVE?
#
# You're spreading harmful misinformation like #COVID19
#
# Send reporters… https://t.co/s3x2nmo9ym
# Lat: None, Long: None
#
# USER  1427957959 karstenwarnecke
# Tweet length:  132
# Polarity:  0.375
# Subjectivity:  0.43333333333333335
# Tweet content:  #COVID19 does not discriminate - even the young, fit &amp; healthy are at risk! 🦠💪😱
# #WeAreAllInThisTogether… https://t.co/8FIYtNg7m4
# Lat: None, Long: None
#
# USER  21084111 JanWillemTulp
# Tweet length:  249
# Polarity:  0.0
# Subjectivity:  0.041666666666666664
# Tweet content:  which #covid19 charts/diagrams communicate something explicitly (and visually) about uncertainty in the data in the… https://t.co/qxrAscqrll
# Lat: None, Long: None
#
# USER  1237443852140716037 MigrantsSales
# Tweet length:  248
# Polarity:  0.32499999999999996
# Subjectivity:  0.45000000000000007
# Tweet content:  Looking For Real and Organic traffic to your website or Online store for more Sales.
# Kindly click on the below link… https://t.co/XIW3HU6sUp
# Lat: None, Long: None
#
# USER  2243353709 Nic4Nack
# Tweet length:  131
# Polarity:  0.325
# Subjectivity:  0.575
# Tweet content:  He speaks to his children and all of his wives like this. They think it’s normal because it’s all they know. We know better. #COVID19
# Lat: None, Long: None
#
# USER  1247275200883949569 tigger_dy
# Tweet length:  87
# Polarity:  0.17500000000000002
# Subjectivity:  0.3166666666666667
# Tweet content:  Be honest... how much time have you spent playing #CallofDuty the last 2 weeks #COVID19
# Lat: None, Long: None
#
# USER  1233343265086300160 Jonoscodpiece
# Tweet length:  213
# Polarity:  0.5
# Subjectivity:  0.35
# Tweet content:  This response here demonstrates the lack of care for the UK population by the current gov't.  The continued rationa… https://t.co/x0RpYNEe0b
# Lat: None, Long: None
#
# USER  1228114294622978049 CloraCrace
# Tweet length:  266
# Polarity:  0.25
# Subjectivity:  0.3333333333333333
# Tweet content:  Hello babies 😅❤️ It’s Cashapp Monday and I’m sending the first 300 people to Like &amp; Retweet this $800–$5000through… https://t.co/v0xE8LKoBw
# Lat: None, Long: None
#
# USER  28931687 DouglasCP
# Tweet length:  211
# Polarity:  0.0
# Subjectivity:  0.0
# Tweet content:  People involved in nuclear issues like @DrDinD @plutoniumpage and @Cirincione know about chain reactions. The sprea… https://t.co/sBhMGzloT5
# Lat: None, Long: None
#
# USER  16488311 Tanger1neDr3ams
# Tweet length:  10
# Polarity:  -0.25
# Subjectivity:  0.8
# Tweet content:  Holy Shit!
# Lat: None, Long: None
#
# USER  800345016023400448 Stacyleehislop
# Tweet length:  81
# Polarity:  0.0
# Subjectivity:  0.0
# Tweet content:  Is this briefing JUST so he can be shitty to reporters? #COVID19 #PressConference
# Lat: None, Long: None
#
# USER  404553582 ivaninloretto
# Tweet length:  251
# Polarity:  0.0
# Subjectivity:  0.3333333333333333
# Tweet content:  Just what the fuck do we make here in Canada 🇨🇦 ? We have no resource industry thanks to the liberals, our automoti… https://t.co/uMnG1HnekU
# Lat: None, Long: None
#
# USER  788296632 cgw62
# Tweet length:  93
# Polarity:  0.4
# Subjectivity:  0.875
# Tweet content:  This guy is a great Trump sound-alike.  It’s about the only way I can bear listening to Trump.
# Lat: None, Long: None
#
# USER  178572466 foildoctrine
# Tweet length:  274
# Polarity:  0.011111111111111118
# Subjectivity:  0.3888888888888889
# Tweet content:  Trump whines about a previous President letting China "get away with absolute murder" - remember, Trump let his fri… https://t.co/FSdFnabEfZ
# Lat: None, Long: None
#
# USER  3036771900 Michaelshackel
# Tweet length:  266
# Polarity:  -0.19166666666666665
# Subjectivity:  0.5833333333333334
# Tweet content:  I was kinda wondering why you would use qnd send a nurse taking care of a covid19 patient to patients that do not h… https://t.co/OO7dIiieNH
# Lat: None, Long: None
#
# USER  703081244 andrewj27868823
# Tweet length:  165
# Polarity:  0.4
# Subjectivity:  0.8
# Tweet content:  The paper that employed Boris Johnson precisely because he wrote nonsensical drivel like this. Get well, soon Boris… https://t.co/0GLMy2pyOR
# Lat: None, Long: None
#
# USER  728180250 ZaRdOz420WPN
# Tweet length:  272
# Polarity:  0.5
# Subjectivity:  0.5
# Tweet content:  @RVAwonk Pharma-Funded Group Tied to a Top Trump Donor Is Promoting Malaria Drug to the President
#
# Founded by one o… https://t.co/rHk7N7leeO
# Lat: None, Long: None
#
# USER  195483947 nickjamespoad
# Tweet length:  130
# Polarity:  0.0
# Subjectivity:  0.3333333333333333
# Tweet content:  Dr Birx quietly dying in the background as this shitshow continues...
#
# #TrumpPressBriefing #MSNBC #COVID19 https://t.co/zyfBadCO8s
# Lat: None, Long: None
#
# USER  47206703 Colttech
# Tweet length:  271
# Polarity:  -0.1471428571428571
# Subjectivity:  0.5664285714285715
# Tweet content:  100% criminal abuse of power and virtual elimination of human rights going on full tilt in both USA and UK.
#
# Covid1… https://t.co/JmXzk5q1Rb
# Lat: None, Long: None
#
# USER  31190561 setholdham
# Tweet length:  280
# Polarity:  0.125
# Subjectivity:  0.3333333333333333
# Tweet content:  With so many Canadians self-isolating at home due to #COVID19, mobile data usage has plummeted and will continue to… https://t.co/iHxqyXdQA7
# Lat: None, Long: None
#
# USER  138177092 thosrose
# Tweet length:  166
# Polarity:  0.3
# Subjectivity:  0.44166666666666665
# Tweet content:  One thing this #COVID19 situation has made clear- many reporters and writers don't understand the implications of f… https://t.co/AuOzcImVRZ
# Lat: None, Long: None
#
# USER  2612203850 sophidescalzi
# Tweet length:  195
# Polarity:  0.16666666666666666
# Subjectivity:  0.3333333333333333
# Tweet content:  .@cathmckenna #CERB overlooks too many including students &amp; recent grads. Will you support the call for income supp… https://t.co/UgmQmATBjc
# Lat: None, Long: None
#
# USER  24530994 SingularMeyer
# Tweet length:  296
# Polarity:  0.0
# Subjectivity:  0.0
# Tweet content:  @SenStroebel @GovEvers Congrats. Wisconsin will become a #COVID19 hotspot in, oh, 15 days or so because of you and… https://t.co/aUZDldqhBD
# Lat: None, Long: None
#
# USER  169191697 stefleggo
# Tweet length:  273
# Polarity:  -0.3666666666666667
# Subjectivity:  0.7666666666666666
# Tweet content:  @realDonaldTrump you are an absolute disgrace to our country &amp; our Presidential office. Never in our history has an… https://t.co/U1JtaPyWU1
# Lat: None, Long: None
#
# USER  898324084882259968 LincolnLisa1
# Tweet length:  302
# Polarity:  0.3125
# Subjectivity:  0.25
# Tweet content:  @DineshDSouza @BilldeBlasio @IngrahamAngle No because Democrats believe it’s a medical procedure and that PLanned P… https://t.co/OrE4gMGEup
# Lat: None, Long: None
#
# USER  823656357333237765 ClownWorldLive
# Tweet length:  123
# Polarity:  -0.4
# Subjectivity:  0.6
# Tweet content:  #DrBirx looking like she is contemplating her poor life decisions... #TrumpPressConference #COVID19 https://t.co/lbp6NDHHfD
# Lat: None, Long: None
#
# USER  23190183 SystemSafetyPro
# Tweet length:  66
# Polarity:  -0.5
# Subjectivity:  1.0
# Tweet content:  @StreetLevelTech To sadly show your point: https://t.co/4tGuEoqk6b
# Lat: None, Long: None
#
# USER  2383832360 JennyKnobZoe
# Tweet length:  269
# Polarity:  0.030303030303030304
# Subjectivity:  0.5227272727272727
# Tweet content:  Hey, y'all. I have some information to share about #covid19. My nephew's gf had a sore throat. She wanted a test be… https://t.co/4xe6TtQ7g5
# Lat: None, Long: None
#
# USER  1015038770 tngadd
# Tweet length:  25
# Polarity:  0.0
# Subjectivity:  0.0
# Tweet content:  This 👇👇👇👇👇👇 #Covid19 #Covid19SA
# Lat: None, Long: None
#
# USER  22867201 zeldalaflame
# Tweet length:  148
# Polarity:  -0.8333333333333334
# Subjectivity:  1.0
# Tweet content:  That is sad, horrific, terrifying. If we do get #Bernie by some hope in hell, we can not abandon people. All those… https://t.co/R8pXUaTV5a
# Lat: None, Long: None
#
# USER  593813785 DonnaYoungDC
# Tweet length:  187
# Polarity:  0.0
# Subjectivity:  0.0
# Tweet content:  Reporter presses again on @OIGatHHS report &amp; testing.
# "We're the federal government. We're not supposed to stand on… https://t.co/USShkzqoFz
# Lat: None, Long: None
#
# USER  837847098179608577 DDunn1234
# Tweet length:  194
# Polarity:  -0.04047619047619047
# Subjectivity:  0.6815476190476191
# Tweet content:  @ddale8 Right. But remind him that healthcare workers must still wait to be tested. Until they are sick. So it is N… https://t.co/8oav17OWkM
# Lat: None, Long: None
#
# USER  386088363 DamainWalsh
# Tweet length:  112
# Polarity:  -0.1
# Subjectivity:  0.1
# Tweet content:  National Guardsman At NY Testing Center Says Media Has Overblown COVID19... https://t.co/FKaTfgAK2P via @YouTube
# Lat: None, Long: None
#
# USER  2209742392 rabiasquared
# Tweet length:  24
# Polarity:  -0.7
# Subjectivity:  0.8
# Tweet content:  No one should be shocked
# Lat: None, Long: None
#
# USER  62327999 drankitbangar
# Tweet length:  233
# Polarity:  0.5375
# Subjectivity:  0.55
# Tweet content:  @covid19indiaorg Please checkout this link with district wise map, and a time series prediction. I’m using your dat… https://t.co/LiIlqfeoIt
# Lat: None, Long: None
#
# USER  828728933076107264 Nowhereurgoin
# Tweet length:  11
# Polarity:  -1.0
# Subjectivity:  1.0
# Tweet content:  Just awful.
# Lat: None, Long: None
#
# USER  44307131 drdeborahbang
# Tweet length:  41
# Polarity:  0.41666666666666663
# Subjectivity:  0.5
# Tweet content:  More data for pregnant #COVID19 patients.
# Lat: None, Long: None
#
# USER  332624154 knightktm
# Tweet length:  278
# Polarity:  0.18809523809523812
# Subjectivity:  0.6101190476190476
# Tweet content:  Inmates in the Philippines, which has the most overcrowded prison system in the world, are at great risk. To stem… https://t.co/7vdBhPnp2e
# Lat: None, Long: None
#
# USER  827397970031030272 ItsMineView
# Tweet length:  249
# Polarity:  0.0
# Subjectivity:  0.0
# Tweet content:  Together we can
# Please Help needy people
# #covid19 #corona #coronavirus
# #help #Prayers #Dua #Islam
# #AwaisAliKhan… https://t.co/6TrxNwTkAs
# Lat: None, Long: None
#
# USER  421454379 AlyssaFafel
# Tweet length:  8
# Polarity:  0.5
# Subjectivity:  1.0
# Tweet content:  Stunning
# Lat: None, Long: None
#
# USER  3098707774 PatricarBel
# Tweet length:  112
# Polarity:  0.25
# Subjectivity:  0.75
# Tweet content:  @HReneeHarvey Alcool 'll NOT help. #alcool can only make more #victims. #Coronavirus @Covid19 #COVID19 #Covid_19
# Lat: None, Long: None
#
# USER  12454882 louisgray
# Tweet length:  271
# Polarity:  0.03409090909090909
# Subjectivity:  0.30113636363636365
# Tweet content:  When I started tracking new #coronavirus cases in Santa Clara County, the number of total cases was doubling every… https://t.co/tABQ1jMgKI
# Lat: None, Long: None
#
# USER  1247288531682279424 DucaJtt
# Tweet length:  73
# Polarity:  0.0
# Subjectivity:  0.0
# Tweet content:  https://t.co/nUvv6xmLqe
# #RIP #Boris #Brexit Johnson #Covid19 #Coronavirus
# Lat: None, Long: None
#
# USER  569200684 ElPasoOEM
# Tweet length:  134
# Polarity:  0.13636363636363635
# Subjectivity:  0.5
# Tweet content:  LIVE: City Officials Provide COVID-19 Update
#
# Watch: https://t.co/HE5bh68Ohg
#
# #COVID19 #CORONAVIRUS #IAMELPASO https://t.co/ZMd6FHSqdC
# Lat: None, Long: None
#
# USER  970489398461632514 EmKL23
# Tweet length:  63
# Polarity:  -0.6999999999999998
# Subjectivity:  0.6666666666666666
# Tweet content:  Never needed to touch my face so bad til you couldn’t 🙈. #COVID19
# Lat: None, Long: None
#
# USER  1356898081 KirstiMiller30
# Tweet length:  88
# Polarity:  0.0
# Subjectivity:  0.5
# Tweet content:  International sports should only resume when a vaccine for #COVID19 is found.
#
# Thoughts?
# Lat: None, Long: None
#
# USER  712199546638508032 gracehwang1970
# Tweet length:  290
# Polarity:  0.225
# Subjectivity:  0.2916666666666667
# Tweet content:  @jsprondel Find, Test &amp; Treat... till get some vaccine on COVID19.
#
# COVID19 is due to Corona virus. Not be Rabies… https://t.co/m01cB4wM8V
# Lat: None, Long: None
#
# USER  758122084253827072 nutz_half
# Tweet length:  74
# Polarity:  0.0
# Subjectivity:  0.0
# Tweet content:  @veeduvidz Gives COVID19 to people
#
# Does some world internet web speed too
# Lat: None, Long: None
#
# USER  748414154977927168 gsandoval1413
# Tweet length:  52
# Polarity:  0.6000000000000001
# Subjectivity:  0.9
# Tweet content:  the springs is doing amazing https://t.co/Br5kYzT1Bc
# Lat: None, Long: None
#
# USER  23162900 pinkbassist
# Tweet length:  140
# Polarity:  0.13636363636363635
# Subjectivity:  0.45454545454545453
# Tweet content:  @Hannah_Furness #harryandmeghan #COVID19 is NOT a timely convenient marketing tool for your new charity. Omg. Nor is your son. #Transparent.
# Lat: None, Long: None
#
# USER  3248832505 NRA_TacoBowl_MS
# Tweet length:  158
# Polarity:  0.0
# Subjectivity:  1.0
# Tweet content:  @WhiteHouse @realDonaldTrump Please see that #Pelosi is investigated for possible insider trading if she bought or… https://t.co/pjuAOAjlQv
# Lat: None, Long: None
#
# USER  1053822166540738560 LRT_TP
# Tweet length:  230
# Polarity:  0.05
# Subjectivity:  0.6083333333333333
# Tweet content:  I kid you not, between the Queen's Speech last night and the PM's deterioration, I believe this dreadful virus has… https://t.co/pM7ckRyIgU
# Lat: None, Long: None
#
# USER  4351803077 PaulPkolin
# Tweet length:  163
# Polarity:  -0.016666666666666663
# Subjectivity:  0.2833333333333334
# Tweet content:  “SMALL BUSINESSES ASSISTANCE” https://t.co/UbiFSoDPjp thanks @MariManoogian @MalloryMcMorrow @RepAndyLevin for putt… https://t.co/L58p5dGOfE
# Lat: None, Long: None
#
# USER  1247153642295005185 Ilona54807291
# Tweet length:  129
# Polarity:  0.048484848484848485
# Subjectivity:  0.3696969696969697
# Tweet content:  don’t take life so seriously have fun and remember you spend each day like it is your last ❤️ #livelife #positive #Covid_19 #COVID19
# Lat: None, Long: None
#
# USER  701589774 sonny9636
# Tweet length:  110
# Polarity:  -0.4
# Subjectivity:  0.6
# Tweet content:  @lizzkatherine_ It’s called institutionalized racism. When resources are scarce, AA will suffer worse. #COVID19
# Lat: None, Long: None
#
# USER  775052094520909824 HuzzahHonzi
# Tweet length:  327
# Polarity:  0.11363636363636363
# Subjectivity:  0.7727272727272727
# Tweet content:  @GovRonDeSantis @FLDEO @FloridaDMS @FloridaRevenue BREAKING: There is growing evidence that COVID19 patients still… https://t.co/zgKrhUtzbr
# Lat: None, Long: None
#
# USER  1021382089059590144 JohnathanPerk
# Tweet length:  270
# Polarity:  -0.19166666666666665
# Subjectivity:  0.30833333333333335
# Tweet content:  The daily #COVID19 press briefings will continue as a cluster of misinformation until literally EVERY reporter who… https://t.co/Dtb8N1LqxY
# Lat: None, Long: None
#
# USER  805147032 olahakeemola
# Tweet length:  23
# Polarity:  0.0
# Subjectivity:  0.0
# Tweet content:  #COVID19 Germany update
# Lat: None, Long: None
#
# USER  4194970521 AUHEATFAN4LIFE
# Tweet length:  99
# Polarity:  0.0
# Subjectivity:  0.0
# Tweet content:  @realDonaldTrump is a disgrace #Briefing_COVID19 #COVID19 #TrumpVirus #TrumpIsTheWORSTPresidentEVER
# Lat: None, Long: None
#
# USER  311856115 SeanBradbery
# Tweet length:  296
# Polarity:  -0.060714285714285714
# Subjectivity:  0.5047619047619047
# Tweet content:  @CultofJack Zero risk of transmission short of a bizarre scenario where someone in the car has asymptomatic COVID19… https://t.co/mU2zgdA0NC
# Lat: None, Long: None
#
# USER  28162211 MaxBoot
# Tweet length:  86
# Polarity:  -0.5
# Subjectivity:  0.6666666666666666
# Tweet content:  Hmmm.... You know who else blindly trusted Xi Jinping? Hint: You used to work for him.
# Lat: None, Long: None
#
# USER  206497236 SCarroll_VDean
# Tweet length:  24
# Polarity:  0.0
# Subjectivity:  0.0
# Tweet content:  Looking forward to this!
# Lat: None, Long: None
#
# USER  287895205 carlyrachman
# Tweet length:  79
# Polarity:  0.37500000000000006
# Subjectivity:  0.7
# Tweet content:  Such an amazing resource for SMB retailers to get online. Thank you @webgility!
# Lat: None, Long: None
#
# USER  48176734 DcalebX
# Tweet length:  128
# Polarity:  -0.4
# Subjectivity:  0.6
# Tweet content:  Donald Trump is unhinged. He is incoherently insulting reporters that aren’t even attacking him and it’s really troubling #Covid19
# Lat: None, Long: None
#
# USER  38242184 and_kell
# Tweet length:  275
# Polarity:  0.25
# Subjectivity:  0.25
# Tweet content:  This lady when the head of @CDCgov admitted on cnn to Sanjay Gupta that #vaccines can cause #autism in children wit… https://t.co/3prNKWDyoe
# Lat: None, Long: None
#
# USER  784900120563290112 DavidFurnessGB
# Tweet length:  273
# Polarity:  -0.06666666666666667
# Subjectivity:  0.13333333333333333
# Tweet content:  #FrontPage of the Daily Mirror on Tuesday 7 April.
#
# Boris Johnson was moved to intensive care amid fears he may hav… https://t.co/MWXbNW3b3g
# Lat: None, Long: None
#
# USER  1024367629560160257 danajlin
# Tweet length:  147
# Polarity:  0.03750000000000002
# Subjectivity:  0.3375
# Tweet content:  Witnessed and experienced a few episodes firsthand these past few weeks. Applaud @MGHRadDiversity  for this panel… https://t.co/409E7NSVed
# Lat: None, Long: None
#
# USER  822464436812345344 dolfanria13
# Tweet length:  54
# Polarity:  -0.125
# Subjectivity:  0.7250000000000001
# Tweet content:  He's gone full out crazy.
# #COVID19 #CoronaVirusUpdates
# Lat: None, Long: None
#
# USER  1239516781330305025 Foaooad
# Tweet length:  233
# Polarity:  0.4
# Subjectivity:  0.1
# Tweet content:  pvl xay ktw qlp xuv pbw jxv oub fbn oae umh joy mav izi rhf spt xbu lgs icb isc jig  COVID CDTV Covid_19 Prior Jorg… https://t.co/dfCxmzdLdo
# Lat: None, Long: None
#
# USER  151929597 _QueenWHIT
# Tweet length:  260
# Polarity:  -0.15952380952380954
# Subjectivity:  0.7523809523809524
# Tweet content:  I wonder if when sick ppl come into the hospital are they injecting them with shit because how tf everybody who wal… https://t.co/AypZHGNl60
# Lat: None, Long: None
#
# USER  1236364823815794688 duwoncong
# Tweet length:  224
# Polarity:  0.0
# Subjectivity:  0.0
# Tweet content:  Marcela Marcela pby van pla pyg jkl upc qrk met iih guo qso qag qxn deo kks dpo bfp dlj kbs wmp msf zkw uat ptq yag… https://t.co/zlcAFTQ9ta
# Lat: None, Long: None
#
# USER  2768097652 Wlfriedman323
# Tweet length:  220
# Polarity:  0.16999999999999998
# Subjectivity:  0.63
# Tweet content:  For the Truth go to https://t.co/SDYh9HLGmK listen to "virus detective" Dr Osterholm @HomieTwonn #COVID19  podcast… https://t.co/qjKTkkGByU
# Lat: None, Long: None
#
# USER  827247504215375874 AmazingDouglass
# Tweet length:  215
# Polarity:  -0.060714285714285714
# Subjectivity:  0.3964285714285714
# Tweet content:  @Yamiche The most vulnerable and least of these before #COVID19 are even more vulnerable afterwards ... The shades… https://t.co/7aoquvWym3
# Lat: None, Long: None
#
# USER  2708800107 WBrauweiler
# Tweet length:  95
# Polarity:  -0.9765625
# Subjectivity:  0.6
# Tweet content:  Dear Mr. President, GROW THE FUCK UP AND TAKE SOME GODDAMN RESPONSIBILITY FOR ONCE!!!! #COVID19
# Lat: None, Long: None
#
# USER  600419206 Busisiwe_prudee
# Tweet length:  195
# Polarity:  0.0
# Subjectivity:  0.0
# Tweet content:  Hi @elysee @swedishPM the world urgently needs a vaccine against #COVID19 — but funds are running out. Will you ste… https://t.co/Pu1hE3uc6O
# Lat: None, Long: None
#
# USER  1101204769165709312 DawnResisting
# Tweet length:  26
# Polarity:  -0.65
# Subjectivity:  1.0
# Tweet content:  So very sad for your loss.
# Lat: None, Long: None
#
# USER  18455693 MattSoleyn
# Tweet length:  46
# Polarity:  0.4
# Subjectivity:  0.35
# Tweet content:  Third rate reporter LOL. #COVID19 #coronavirus
# Lat: None, Long: None
#
# USER  588559274 TheLigerLivesOn
# Tweet length:  44
# Polarity:  -0.75
# Subjectivity:  1.0
# Tweet content:  This is beyond horrible!!! #wtf #coronavirus
# Lat: None, Long: None
#
# USER  1222248524378710022 TruthTo59816979
# Tweet length:  36
# Polarity:  0.0
# Subjectivity:  0.0
# Tweet content:  Trailer trash Barbie @KellyannePolls
# Lat: None, Long: None
#
# USER  92050345 ImperialChaos
# Tweet length:  35
# Polarity:  0.5333333333333333
# Subjectivity:  0.4666666666666666
# Tweet content:  Wedlock has never been more fun lol
# Lat: None, Long: None
#
# USER  741927387894558721 therealgruffy
# Tweet length:  94
# Polarity:  0.0
# Subjectivity:  0.0
# Tweet content:  Admiral Brett Giroir vs #JoeExotic #TheTigerKing #Coronavirus #COVID19 https://t.co/5K9hmFE6BR
# Lat: None, Long: None
#
# USER  729115213 BombKen
# Tweet length:  21
# Polarity:  0.0
# Subjectivity:  0.0
# Tweet content:  GETTING ME ONE!!!!!!!
# Lat: None, Long: None
#
# USER  3285660648 lengedmd
# Tweet length:  25
# Polarity:  0.0
# Subjectivity:  0.0
# Tweet content:  SDOH on display
# #SocialEM
# Lat: None, Long: None
#
# USER  1232329071398465536 Moparmama79
# Tweet length:  283
# Polarity:  0.10681818181818181
# Subjectivity:  0.3738636363636364
# Tweet content:  An email from Superstore to me:  We are writing to inform you that a worker has recently tested positive on a presu… https://t.co/F11wDvbQyA
# Lat: None, Long: None
#
# USER  1416036044 BethCalvertNYC
# Tweet length:  86
# Polarity:  0.0
# Subjectivity:  0.0
# Tweet content:  Everyone on that stage should walk off #TrumpIsADisgrace #TrumpLiedPeopleDied #COVID19
# Lat: None, Long: None
#
# USER  1561135860 FHFund
# Tweet length:  153
# Polarity:  -0.25
# Subjectivity:  0.4
# Tweet content:  ICYMI: Minneapolis will offer assistance for rent and utilities,   as well as support for small businesses impacted… https://t.co/MBOOyq6Btz
# Lat: None, Long: None
#
# USER  958076462652903424 armandalegshow
# Tweet length:  245
# Polarity:  -0.15555555555555559
# Subjectivity:  0.2888888888888889
# Tweet content:  The news keeps creating stories faster than we can produce ‘em.
#
# This is one of a kajillion instances of clinics a… https://t.co/Z6DDeHYhFo
# Lat: None, Long: None
#
# USER  1227343187120992256 patbuchananphd
# Tweet length:  89
# Polarity:  0.9
# Subjectivity:  1.0
# Tweet content:  The lights are brilliant. We see all that is happening “under cover” of the COVID19 crisis.
# Lat: None, Long: None
#
# USER  56255715 heeman82
# Tweet length:  121
# Polarity:  0.43424479166666663
# Subjectivity:  0.31666666666666665
# Tweet content:  "You're a third rate reporter, and what you just said is a disgrace, ok?"
# Classic @realDonaldTrump !! Love it!!! #COVID19
# Lat: None, Long: None
#
# USER  1201938298689728512 Agba_Gee
# Tweet length:  50
# Polarity:  -0.2
# Subjectivity:  0.15000000000000002
# Tweet content:  Bae wan justify her action...washere eyan #COVID19
# Lat: None, Long: None
#
# USER  16370306 hoffmeister262
# Tweet length:  211
# Polarity:  0.0
# Subjectivity:  0.0
# Tweet content:  Well, there's THIS. https://t.co/UAQQWZLHvN @Gothamist GD WILL NOT SAVE YOU. What part of #COVID19  do you not unde… https://t.co/rLDQ7VERcT
# Lat: None, Long: None
#
# USER  155798348 jfaycook
# Tweet length:  181
# Polarity:  0.6
# Subjectivity:  1.0
# Tweet content:  @TeamTrump @realDonaldTrump President Trump, Stormy Daniels and Jared Kushner own stock in Hydroxychloroquine. That… https://t.co/oTZwgcm0Ar
# Lat: None, Long: None
#
# USER  18023868 MassGovernor
# Tweet length:  304
# Polarity:  0.5
# Subjectivity:  0.5
# Tweet content:  Remember to stay home if you feel COVID-19 symptoms (fever, cough, shortness of breath).
#
# With @buoyhealth's online… https://t.co/K3wWnTAf3e
# Lat: None, Long: None
#
# USER  890548855 DazSmiles91
# Tweet length:  201
# Polarity:  0.0
# Subjectivity:  0.0
# Tweet content:  Retweet and Share 👏👏👏 @10DowningStreet #PrayForBoris #BorisJohnson #BorisJohnsonCoronavirus #ClapForBoris #COVID19… https://t.co/GMJn3BBmgR
# Lat: None, Long: None
#
# USER  166326763 GlobalPandemics
# Tweet length:  191
# Polarity:  0.0
# Subjectivity:  0.0
# Tweet content:  COVID-ALERT: Millions of Chinese-Made Coronavirus Tests Bought By British Government Don’t Work - Global Pandemic N… https://t.co/sTRpvMEyHg
# Lat: None, Long: None
#
# USER  968501746619289600 randomR3dbeard
# Tweet length:  50
# Polarity:  0.0
# Subjectivity:  0.0
# Tweet content:  These daily press conferences are a joke. #COVID19
# Lat: None, Long: None
#
# USER  32361931 STARING_KRYSTAL
# Tweet length:  223
# Polarity:  -0.25
# Subjectivity:  0.55
# Tweet content:  Authorities: Illinois man's COVID-19 worries prompt murder-suicide | I find this difficult to believe this smacks o… https://t.co/hVXge2MAq3
# Lat: None, Long: None
#
# USER  13104432 kenfagerdotcom
# Tweet length:  25
# Polarity:  0.26666666666666666
# Subjectivity:  0.95
# Tweet content:  Absolutely cringe worthy.
# Lat: None, Long: None
#
# USER  1069326393849331717 puropedo666
# Tweet length:  88
# Polarity:  -0.43333333333333335
# Subjectivity:  0.7999999999999999
# Tweet content:  Wtf is wrong with Trump? “You’re not going to make it” common man. #COVID19 #TrumpIsALooser
# Lat: None, Long: None
#
# USER  38890794 BELLEionaire
# Tweet length:  36
# Polarity:  0.3571428571428571
# Subjectivity:  0.5357142857142857
# Tweet content:  Oh when the saints go right to hell!
# Lat: None, Long: None
#
# USER  107397492 batarizu
# Tweet length:  8
# Polarity:  0.0
# Subjectivity:  0.0
# Tweet content:  Surprise
# Lat: None, Long: None
#
# USER  26930500 RICwithnoK
# Tweet length:  5
# Polarity:  0.0
# Subjectivity:  0.0
# Tweet content:  Gtfoh
# Lat: None, Long: None
#
# USER  600419206 Busisiwe_prudee
# Tweet length:  185
# Polarity:  0.0
# Subjectivity:  0.0
# Tweet content:  This #WorldHealthDay will all @g20org states step up funding to help @WHO to protect the world’s poorest against… https://t.co/igSLttCFWF
# Lat: None, Long: None
#
# USER  1187126588 HankRearden91
# Tweet length:  85
# Polarity:  0.0
# Subjectivity:  0.0
# Tweet content:  @OrwellNGoode The COVID19 and its consequences have
# been a disaster for the feminism.
# Lat: None, Long: None
#
# USER  1004065528871247872 RobBontaCA
# Tweet length:  234
# Polarity:  -0.14583333333333334
# Subjectivity:  0.34226190476190477
# Tweet content:  CA has secured 4,613 beds at alternative care sites. CA is working hard to prepare for the anticipated surge in… https://t.co/BjtGSqkLVH
# Lat: None, Long: None
#
# USER  775052094520909824 HuzzahHonzi
# Tweet length:  341
# Polarity:  0.11363636363636363
# Subjectivity:  0.7727272727272727
# Tweet content:  @EcoSexuality @GovRonDeSantis @FLDEO @FloridaDMS @FloridaRevenue BREAKING: There is growing evidence that COVID19 p… https://t.co/aZnigNr7xe
# Lat: None, Long: None
#
# USER  1307611178 Agnes_Kalibata
# Tweet length:  283
# Polarity:  0.0
# Subjectivity:  0.5
# Tweet content:  Three things we must do 2prevent a food crisis in the wake of #COVID19 crisis are explained in these blogs: Support… https://t.co/YA9PBLi838
# Lat: None, Long: None
#
# USER  32060819 slounsbury
# Tweet length:  62
# Polarity:  0.2
# Subjectivity:  0.2
# Tweet content:  He is taking meds from people who really NEED them for trials.
# Lat: None, Long: None
#
# USER  2587381476 ali28may
# Tweet length:  307
# Polarity:  0.016666666666666663
# Subjectivity:  0.27777777777777773
# Tweet content:  @WhiteHouse @realDonaldTrump Trump knows what Dr Fauci and all virologists dont. First he recklessly dismissed Covi… https://t.co/F3kOeBaaZ1
# Lat: None, Long: None
#
# USER  716411928025907200 NigilHaroon
# Tweet length:  302
# Polarity:  0.07500000000000001
# Subjectivity:  0.575
# Tweet content:  USA and Canada trends. Potential factors: Early intervention, Difference in population at risk, Pop Density, Citize… https://t.co/9RY6Ilz2Wl
# Lat: None, Long: None
#
# USER  19244813 comma_police
# Tweet length:  57
# Polarity:  0.0
# Subjectivity:  0.0
# Tweet content:  News flash: Iowa still has bingo halls #COVID19 #StayHome
# Lat: None, Long: None
#
# USER  60740694 SoozleMcDoozle
# Tweet length:  88
# Polarity:  0.5
# Subjectivity:  0.5
# Tweet content:  Ok Iowans (and anyone else)
# What should we call @IAGovernor?
# #COVID19 #ShelterInPlaceIA
# Lat: None, Long: None
#
# USER  237338279 diegovonvacano
# Tweet length:  37
# Polarity:  0.0
# Subjectivity:  0.0
# Tweet content:  Pray for Boris #COVID19 #BorisJohnson
# Lat: None, Long: None
#
# USER  1151678433644220416 Jabir97356233
# Tweet length:  85
# Polarity:  0.0
# Subjectivity:  0.0
# Tweet content:  A picture of the day - Herat province, #Afghanistan
# #COVID19 https://t.co/ul6tj4NX4z
# Lat: None, Long: None
#
# USER  1230572206029078528 DesiIfied
# Tweet length:  264
# Polarity:  0.11499999999999999
# Subjectivity:  0.3914285714285714
# Tweet content:  @ImtiazMadmood We have many such pay and get in Universities which beat 5 star hotels in both decor &amp; services! The… https://t.co/FGheciOdzN
# Lat: None, Long: None
#
# USER  789576444267540480 rockingchairmom
# Tweet length:  234
# Polarity:  0.171875
# Subjectivity:  0.4375
# Tweet content:  Why Maxine --- Hydroxychloroquine to treat #COVID19 has proven to work!!   Many other countries are using it and pr… https://t.co/FnBuHXRleG
# Lat: None, Long: None
#
# USER  373732965 Skashoon
# Tweet length:  277
# Polarity:  0.0703125
# Subjectivity:  0.4125
# Tweet content:  Prescisely correct. And look at natural cures that are suppressed by BigPharma through their deputy FDA. Most major… https://t.co/UgkOMn24WL
# Lat: None, Long: None
#
# USER  27863698 BobNBC4
# Tweet length:  46
# Polarity:  -0.05
# Subjectivity:  0.4
# Tweet content:  Did you ever notice weekdays being this long? 😃
# Lat: None, Long: None
#
# USER  3886909274 LUTVNews7
# Tweet length:  278
# Polarity:  0.05
# Subjectivity:  0.2625
# Tweet content:  On @LUTVNews7, host Jonathan Tippett talks with #LamarUniversity president Dr. Kenneth Evans about how the institut… https://t.co/72HKofrPQP
# Lat: None, Long: None
#
# USER  1242684073627095040 baoering
# Tweet length:  216
# Polarity:  0.0
# Subjectivity:  0.0
# Tweet content:  bafe enlm frye unca nqim ywyy rwtz pock qazv nbwl bcgi  COVID CDTV Covid_19 Prior Jorge Babu Manu ForaPrior David M… https://t.co/NHAUQaHnVO
# Lat: None, Long: None
#
# USER  342922268 sfbay
# Tweet length:  234
# Polarity:  0.55
# Subjectivity:  0.75
# Tweet content:  The bright beacon atop the Transamerica Pyramid will light up each night as a symbol of hope and in solidarity with… https://t.co/Se8XDCHX9k
# Lat: None, Long: None
#
# USER  185952368 RudeboyReez
# Tweet length:  45
# Polarity:  0.0
# Subjectivity:  0.0
# Tweet content:  Ima keep my petty #covid19 comments to myself
# Lat: None, Long: None
#
# USER  3246950598 SharlieMello
# Tweet length:  278
# Polarity:  0.19999999999999998
# Subjectivity:  0.7000000000000001
# Tweet content:  I would be curious to know if there are any patients w/lupus who take this drug and who have developed COVID19? Has… https://t.co/sJqVoPxxCU
# Lat: None, Long: None
#
# USER  148756631 CTIronman
# Tweet length:  32
# Polarity:  -0.016666666666666666
# Subjectivity:  0.06666666666666667
# Tweet content:  Not much social distancing here.
# Lat: None, Long: None
#
# USER  4096463059 theterradactyle
# Tweet length:  92
# Polarity:  0.25
# Subjectivity:  0.3333333333333333
# Tweet content:  first quarantine promposal? thank you lovey❤️ #COVID19 #SocialDistance https://t.co/hH8QHuaI0q
# Lat: None, Long: None
#
# USER  37353155 DawnWhiteNews
# Tweet length:  91
# Polarity:  0.35
# Subjectivity:  0.55
# Tweet content:  Prayers for a full recovery for @BorisJohnson and all those battling #COVID19 #coronavirus.
# Lat: None, Long: None
#
# USER  1190397186300887041 michaelpbroache
# Tweet length:  83
# Polarity:  0.0
# Subjectivity:  0.0
# Tweet content:  Fluoxetine, 40 mg (as prescribed)
#
# Also, exercise and trying to remember to hydrate
# Lat: None, Long: None
#
# USER  1808431 adrianafreitas
# Tweet length:  129
# Polarity:  0.3
# Subjectivity:  0.2
# Tweet content:  Coronavirus Search Trends - @Google Trends
# Fun facts
#
# #COVID19 #StayAtHome #MeQuedoEnCasa #EuFicoEmCasa  https://t.co/jTHB9XpGfb
# Lat: None, Long: None
#
# USER  1241427478251540482 BardBrite
# Tweet length:  195
# Polarity:  0.0
# Subjectivity:  0.0
# Tweet content:  Released by EVMS - Dr. Paul Marik MD protocol for #COVID19.  https://t.co/ad6ibfnw9s #TrumpPressBriefing  this incl… https://t.co/ZkhqG1PalQ
# Lat: None, Long: None
#
# USER  317566241 drewthfully
# Tweet length:  6
# Polarity:  -1.0
# Subjectivity:  1.0
# Tweet content:  Awful.
# Lat: None, Long: None
#
# USER  1243692647669252102 CitzSanctuary
# Tweet length:  254
# Polarity:  0.0
# Subjectivity:  0.125
# Tweet content:  Conservative Review with @RMConservative
# Ep 616 | Locking Up Americans, Releasing Criminals, and Flying In Chinese… https://t.co/SVejSbs0xE
# Lat: None, Long: None
#
# USER  1354889300 rajshantanu7
# Tweet length:  229
# Polarity:  0.3020833333333333
# Subjectivity:  0.6083333333333333
# Tweet content:  @maniizeh True, here is the link of an article by World Economic Forum which shows the rise in number of users of Z… https://t.co/wMzz5H8cS5
# Lat: None, Long: None
#
# USER  1238374249129074688 tchirkine
# Tweet length:  140
# Polarity:  0.1875
# Subjectivity:  0.6499999999999999
# Tweet content:  Sickest leader since 1945! Adi Amin, Pol Pot... Makes Capt Queeg  look stable. The Kim family is closer to normal!… https://t.co/eoFKySAm8L
# Lat: None, Long: None
#
# USER  724354979784347648 BigSisterTweets
# Tweet length:  282
# Polarity:  0.3603125
# Subjectivity:  0.4225
# Tweet content:  A cousin of ours is in her senior year of high school and is missing prom, senior trip, &amp; graduation. Praying for a… https://t.co/ak30d1bkq4
# Lat: None, Long: None
#
# USER  80410299 NewsNatasha
# Tweet length:  276
# Polarity:  0.0
# Subjectivity:  0.4
# Tweet content:  President Trump: The states &amp; the hospitals are supposed to be doing the #COVID19 testing. Calls reporter’s related… https://t.co/wq13TpkhMd
# Lat: None, Long: None
#
# USER  775052094520909824 HuzzahHonzi
# Tweet length:  290
# ...
# Subjectivity:  0.0
# Tweet content:  Still a valid comment
# Lat: None, Long: None
#
# USER  484449533 dgmtick1
# Tweet length:  120
# Polarity:  0.25
# Subjectivity:  0.75
# Tweet content:  @JohnCornyn America had many months to prepare but trump called covid19 a hoax and created the massive US Trump Pandemic
# Lat: None, Long: None
#
# USER  2801237150 yunuennnn
# Tweet length:  49
# Polarity:  0.032467532467532464
# Subjectivity:  0.3344155844155844
# Tweet content:  Every single day there’s a handful of new cases. I—
# Lat: None, Long: None
#
# USER  298652581 enough14
# Tweet length:  177
# Polarity:  0.0
# Subjectivity:  0.0
# Tweet content:  #Lasttweet a German (Deutsche) version of Giorgio Ambagen's piece "Reflections on the plague" - Introduction and tr… https://t.co/BrKOPZqN5S
# Lat: None, Long: None
#
# USER  19777195 JenLWat
# Tweet length:  280
# Polarity:  0.3125
# Subjectivity:  0.55
# Tweet content:  @VP @SecAzar @SteveFDA @CDCDirector @IAGovernor Watching @realDonaldTrump argue at press conf there's no problem ge… https://t.co/GSSJXjprrX
# Lat: None, Long: None
#
# USER  839235909203656704 mikewizz1960
# Tweet length:  160
# Polarity:  -0.2
# Subjectivity:  0.8
# Tweet content:  @nwwilson @chris_sutton73 I hope he recovers so he can be accountable for Demonic Cummings  and all the shit foiste… https://t.co/5LSVxmzTJu
# Lat: None, Long: None
#
# USER  248880266 pcolpitts11
# Tweet length:  50
# Polarity:  0.0
# Subjectivity:  0.0
# Tweet content:  #BiohazardInChief a savage dick tonight.  #COVID19
# Lat: None, Long: None
#
# USER  1035044773 mindfulhealth1
# Tweet length:  174
# Polarity:  0.0
# Subjectivity:  0.0
# Tweet content:  A #Covid19 #vaccine in 18 months?
#
# Let's make room for those who know, explain what's involved in making a vaccine.… https://t.co/14ETLKkg5h
# Lat: None, Long: None
#
# USER  1126501826 AndreaAshNews
# Tweet length:  312
# Polarity:  0.21212121212121213
# Subjectivity:  0.3737373737373737
# Tweet content:  DATA UPDATE | Kentucky &amp; Indiana new #Coronavirus cases from day to day
#
# TODAY MARKS ONE MONTH SINCE FIRST CASE IN… https://t.co/zHIT4MI6IT
# Lat: None, Long: None
#
# USER  1111990125226012672 SanazKyllani
# Tweet length:  122
# Polarity:  0.0
# Subjectivity:  0.0
# Tweet content:  🥰Tweeter !!!
# 😡Please suspend @AmbChangHua's account.
# 😤The ambassador of China, the country that spread #COVID19 to the world.
# Lat: None, Long: None
#
# USER  138889690 OMallon
# Tweet length:  180
# Polarity:  0.02232142857142857
# Subjectivity:  0.5116071428571429
# Tweet content:  @todd_winger Certainly hoping he can come out the other side well. I’m no fan of Johnson from a political perspecti… https://t.co/yWlryDG9Ay
# Lat: None, Long: None
#
# USER  2744586995 CCaligirl08
# Tweet length:  185
# Polarity:  0.4375
# Subjectivity:  0.55
# Tweet content:  @mashable Watch full Egyptian video shows  2 drugs curing #COVID19
# https://t.co/pYBIyBM7Hg please share and let Do… https://t.co/hUL0rLsmel
# Lat: None, Long: None
#
# USER  1243600709402181634 candidcorona
# Tweet length:  275
# Polarity:  0.3
# Subjectivity:  0.75
# Tweet content:  @Yamiche My stomach just dropped.
#
# Every day there's one more fact that just makes the tragedy of the day before s… https://t.co/yvJxDmUbPm
# Lat: None, Long: None
#
# USER  355232443 scupe007
# Tweet length:  180
# Polarity:  0.10000000000000002
# Subjectivity:  0.6833333333333332
# Tweet content:  Where did this so-called President come from.  He is a complete and total discrace.  The media should absolutely bo… https://t.co/Mnxnrfajnh
# Lat: None, Long: None
#
# USER  919107158 BrillBkfast
# Tweet length:  77
# Polarity:  0.0
# Subjectivity:  0.625
# Tweet content:  @realDonaldTrump  is a genocidal monster.  And the entire @GOP  is complicit.
# Lat: None, Long: None
#
# USER  458068072 sammie_only
# Tweet length:  192
# Polarity:  -0.125
# Subjectivity:  0.5694444444444444
# Tweet content:  Due to #COVID19 aka #Coronavirus Ill be sending the first 700 people to like &amp; retweet this $700 -$17,890 through C… https://t.co/Lj41tWL8ht
# Lat: None, Long: None
#
# USER  3082736104 rachel_martini8
# Tweet length:  42
# Polarity:  0.0
# Subjectivity:  0.0
# Tweet content:  Please pass onto the seniors in your life!
# Lat: None, Long: None
#
# USER  31339542 nana2hallie
# Tweet length:  46
# Polarity:  -0.03181818181818183
# Subjectivity:  0.65
# Tweet content:  He is losing his shit on live TV @GOP #COVID19
# Lat: None, Long: None
#
# USER  703762547581820932 sue_bdg
# Tweet length:  178
# Polarity:  0.0
# Subjectivity:  0.75
# Tweet content:  If I was a reporter at this press conference my only question to tRump would be “why are you such an asshole?”… https://t.co/sm9gqVYSfs
# Lat: None, Long: None
#
# USER  269809897 etoller
# Tweet length:  92
# Polarity:  0.0
# Subjectivity:  0.0
# Tweet content:  Helpful one-stop-shop for anyone looking for information about health products and COVID-19.
# Lat: None, Long: None
#
# USER  593813785 DonnaYoungDC
# Tweet length:  126
# Polarity:  0.0
# Subjectivity:  0.0
# Tweet content:  Trump then tells the reporter she's "horrid" in the way she asked her question about @OIGatHHS report &amp; testing.
#
# #COVID19
# Lat: None, Long: None
#
# USER  23759742 mujawed
# Tweet length:  111
# Polarity:  0.0
# Subjectivity:  0.0
# Tweet content:  @WallStPlayboys Dr said this already https://t.co/B7SEvCtZnc then there is this as well https://t.co/CcmfT3amZp
# Lat: None, Long: None
#
# USER  830756430672191488 cindy_vito
# Tweet length:  39
# Polarity:  0.0
# Subjectivity:  0.0
# Tweet content:  Now I want to watch these movies again 😭
# Lat: None, Long: None
#
# USER  1220465910630244352 AlwaysRC12
# Tweet length:  162
# Polarity:  0.18333333333333335
# Subjectivity:  0.7999999999999999
# Tweet content:  I FN Love these #CoronaVirusUpdate The way the Prez handles these appalling #Fakenews reporters is fantastic. Must… https://t.co/xJj4rKitya
# Lat: None, Long: None
#
# USER  2835703477 cofchristcwm
# Tweet length:  270
# Polarity:  0.10227272727272727
# Subjectivity:  0.4301948051948052
# Tweet content:  In times of uncertainty, remember that we have the ability to discover new truths by simply revisiting the scriptur… https://t.co/XOYFRuFb8p
# Lat: None, Long: None
#
# USER  1241362113416892417 OwenOrnz
# Tweet length:  252
# Polarity:  0.0
# Subjectivity:  0.0
# Tweet content:  @jameelajamil I guess being in the US you’re not feeling the emotion of the country. Our leader is in intensive car… https://t.co/VvmNCuV3JV
# Lat: None, Long: None
#
# USER  373549066 meghannicole352
# Tweet length:  176
# Polarity:  -0.059375
# Subjectivity:  0.5
# Tweet content:  The fact that the highlight of my weekend was jogging past a mildly hot dude tells me that I’ve been in quarantine… https://t.co/WJVi523704
# Lat: None, Long: None
#
# USER  45900110 brazospix
# Tweet length:  43
# Polarity:  0.4
# Subjectivity:  1.0
# Tweet content:  Important COVID Patient Recovery Thread... 👇🧐
# Lat: None, Long: None
#
# USER  20740575 CityofBerkeley
# Tweet length:  299
# Polarity:  0.2
# Subjectivity:  0.2
# Tweet content:  We have grants of up to $25,000 available for Berkeley-based nonprofit arts orgs grappling with the financial impac… https://t.co/vY26xZTpeF
# Lat: None, Long: None
#
# USER  815215030140596228 jojobear2553
# Tweet length:  37
# Polarity:  1.0
# Subjectivity:  1.0
# Tweet content:  Her children must be so proud of her!
# Lat: None, Long: None
#
# USER  534763333 not_gabriela
# Tweet length:  233
# Polarity:  -0.5
# Subjectivity:  1.0
# Tweet content:  Some of you might have noticed that Missouri's #COVID19 case count for Boone County (76) does not align with the co… https://t.co/I7ny57KbwG
# Lat: None, Long: None
#
# USER  754804362749341696 GatorViking56
# Tweet length:  165
# Polarity:  0.23095238095238094
# Subjectivity:  0.5920634920634921
# Tweet content:  @QTRResearch It’s true :) Its so funny that the “short eff” funds for S&amp;P and Nasdaq are trading right now are at w… https://t.co/foTmE6Ma7K
# Lat: None, Long: None
#
# USER  944524401877319680 KModitambi
# Tweet length:  185
# Polarity:  0.0
# Subjectivity:  0.0
# Tweet content:  This #WorldHealthDay will all @g20org states step up funding to help @WHO to protect the world’s poorest against… https://t.co/iznEDFpSMu
# Lat: None, Long: None
#
# USER  62352016 DeanRavenMusic
# Tweet length:  58
# Polarity:  0.0
# Subjectivity:  0.0
# Tweet content:  #Contagion is literally the movie of Covid19 made in 2011 😳
# Lat: None, Long: None
#
# USER  534763333 not_gabriela
# Tweet length:  129
# Polarity:  0.5
# Subjectivity:  0.5
# Tweet content:  I'll have all of that and even more included in the state #COVID19 roundup Springfield's @ahuguelet wrote today. @columbiatribune
# Lat: None, Long: None
#
# USER  1253839952 cr2032
# Tweet length:  298
# Polarity:  -0.25
# Subjectivity:  0.4583333333333333
# Tweet content:  Family with odd sore throats + congestion and tiredness. Now *me* with all that. Can't be flu, flu shot and all. Ca… https://t.co/TozPB6kdhR
# Lat: None, Long: None
#
# USER  760098215702110208 robgo84
# Tweet length:  130
# Polarity:  -0.1875
# Subjectivity:  0.5
# Tweet content:  This. Fight for healthcare for all. This is what happens when a segment of our communities have little or no access… https://t.co/imSZcuD7gi
# Lat: None, Long: None
#
# USER  1543936286 sisterdawnmarie
# Tweet length:  106
# Polarity:  0.3333333333333333
# Subjectivity:  0.3333333333333333
# Tweet content:  @Dvickery73 Our local hospital has many COVID19 patients on vents. We're getting more refrigerated trucks.🙏
# Lat: None, Long: None
#
# USER  544030000 TheNatharian
# Tweet length:  104
# Polarity:  0.2
# Subjectivity:  0.30000000000000004
# Tweet content:  @WhiteHouse @POTUS How about you take responsibility for something real for once
# https://t.co/8kh8GHZ3Xq
# Lat: None, Long: None
#
# USER  20656521 sweeneymcqueen
# Tweet length:  164
# Polarity:  -0.5125
# Subjectivity:  0.76
# Tweet content:  “You should ask…“ #POTUS may think he’s the BSD, in charge of the #COVID19 briefing, but by attacking the media he… https://t.co/QYSoWDMulJ
# Lat: None, Long: None
#
# USER  142608832 rikwes66
# Tweet length:  166
# Polarity:  0.13636363636363635
# Subjectivity:  0.5
# Tweet content:  time to end the live feed, CNN ... this asshole is never going to answer any question  and there isn't any newsvalu… https://t.co/UcSNxwrDOi
# Lat: None, Long: None
#
# USER  18455693 MattSoleyn
# Tweet length:  78
# Polarity:  0.0
# Subjectivity:  0.0
# Tweet content:  Jonathan Karl “third rate reporter” says President #Trump. #COVID19 #coronavirus
# Lat: None, Long: None
#
# USER  3251189926 stevecripe57
# Tweet length:  133
# Polarity:  0.3875
# Subjectivity:  0.575
# Tweet content:  Sound advice for anyone dealing with the virus at home from a Queen's Hospital (UK) Physician. Original tweet court… https://t.co/CCUh5dzNYZ
# Lat: None, Long: None
#
# USER  1135699861 Spfarmer1Steve
# Tweet length:  16
# Polarity:  0.0
# Subjectivity:  0.0
# Tweet content:  Thank you David.
# Lat: None, Long: None
#
# USER  4913320595 Only_rock_radio
# Tweet length:  193
# Polarity:  0.4
# Subjectivity:  0.5
# Tweet content:  enjoy our friends Corner Table Remake by Paleosonik @paleosonik On https://t.co/tmYHgdAL43 #SocialDistancing… https://t.co/J9IU7ZEMyI
# Lat: None, Long: None
#
# USER  757300766478663680 DrJacobsRad
# Tweet length:  37
# Polarity:  0.0
# Subjectivity:  0.0
# Tweet content:  Thank you!
#
# #COVID19 #Cdnpoli #Abpoli
# Lat: None, Long: None
#
# USER  1344951 WIRED
# Tweet length:  250
# Polarity:  0.0
# Subjectivity:  0.0
# Tweet content:  #Covid19 has inspired all sorts of schemes to exploit people’s fear and uncertainty, from phishing campaigns to pri… https://t.co/M0jmqoj2gC
# Lat: None, Long: None
#
# USER  2892811589 mfox207
# Tweet length:  278
# Polarity:  -0.18333333333333335
# Subjectivity:  0.35000000000000003
# Tweet content:  #NBC news, central Indiana, Channel 13 just REPEATED everything about Trump calling hydroxychloroquine a miracle dr… https://t.co/6c0doYl1KQ
# Lat: None, Long: None
#
# USER  956588032299356160 AnalyzeEvidence
# Tweet length:  71
# Polarity:  0.25
# Subjectivity:  0.5
# Tweet content:  @ASavageNation You might be interested in this: https://t.co/LbABBYKfSQ
# Lat: None, Long: None
#
# USER  1038952235550564352 786_mamoon
# Tweet length:  294
# Polarity:  -0.125
# Subjectivity:  0.5879629629629629
# Tweet content:  I’m not sure if it’s me or if any one else has seen this too,but I’m definitely concerned on UK’s recovered rate co… https://t.co/2LSNjiZM20
# Lat: None, Long: None
#
# USER  5513002 Marmel
# Tweet length:  154
# Polarity:  -0.5333333333333333
# Subjectivity:  0.6416666666666667
# Tweet content:  "Trump hates who I hate" equals "Trump kills who I hate."
#
# This news broke the same day the Governor of Louisiana d… https://t.co/e3rRs3yGHd
# Lat: None, Long: None
#
# USER  1465138716 okchdg
# Tweet length:  133
# Polarity:  0.6125
# Subjectivity:  0.75
# Tweet content:  @GovStitt It would be nice to have the support of our governor.  @davidfholt will okc see anything like this?  We h… https://t.co/QOF5JiRD59
# Lat: None, Long: None
#
# USER  1038818336 coolmikeLLC
# Tweet length:  15
# Polarity:  -0.25
# Subjectivity:  0.25
# Tweet content:  Lying as usual.
# Lat: None, Long: None
#
# USER  74466941 MahmoudCanada
# Tweet length:  264
# Polarity:  -0.039999999999999945
# Subjectivity:  0.5783333333333334
# Tweet content:  @_shireenahmed_ @Indigenia @elamin88 I am @ManUtd fan, but I had to learn not to focus on our differences.
# In a wei… https://t.co/J9VWXORSW2
# Lat: None, Long: None
#
# USER  495174506 dcfhockeyfoo
# Tweet length:  245
# Polarity:  0.27499999999999997
# Subjectivity:  0.5499999999999999
# Tweet content:  This is not true. If you were doing EVERYTHING you can, you would do more than tinkering at the edges of your priso… https://t.co/VwWjAqQU2V
# Lat: None, Long: None
#
# USER  14855972 gyamashita
# Tweet length:  109
# Polarity:  -0.056249999999999994
# Subjectivity:  0.44375
# Tweet content:  translation: whenever tRump or his minions say "no one," they really just mean tRump. #unfit #COVID19 #70days
# Lat: None, Long: None
#
# USER  724021434603982850 DonnaCiraFood88
# Tweet length:  278
# Polarity:  -0.0125
# Subjectivity:  0.3416666666666667
# Tweet content:  @nytimes Millions of people whose lives depend on hydroxychloroquine to treat lupus changed in that brief moment wh… https://t.co/6HN5E5brdU
# Lat: None, Long: None
#
# USER  1225515801425391617 Muller_Tough
# Tweet length:  251
# Polarity:  0.325
# Subjectivity:  0.47500000000000003
# Tweet content:  Dear @Armagan_caglaya , will you be so kind as to support our idea of releasing the innocent political prisoners fr… https://t.co/RUjqp0zp9z
# Lat: None, Long: None
#
# USER  2899641212 Code5Idaho
# Tweet length:  92
# Polarity:  0.0
# Subjectivity:  0.0
# Tweet content:  Trump is UNHINGED!
#
# #TrumpPressBriefing #Trump2020 #TrumpVirus #TrumpLiedPeopleDied #COVID19
# Lat: None, Long: None
#
# USER  289804730 fabfreshandfly
# Tweet length:  54
# Polarity:  -0.06666666666666665
# Subjectivity:  0.775
# Tweet content:  Ridiculous. Those pastors need to be held responsible.
# Lat: None, Long: None
#
# USER  2587381476 ali28may
# Tweet length:  295
# Polarity:  0.016666666666666663
# Subjectivity:  0.27777777777777773
# Tweet content:  @realDonaldTrump Trump knows what Dr Fauci and all virologists dont. First he recklessly dismissed Covid19 alert an… https://t.co/4w1Vt6xIyw
# Lat: None, Long: None
#
# USER  183444822 monseisfly
# Tweet length:  16
# Polarity:  -1.0
# Subjectivity:  1.0
# Tweet content:  Just F horrible.
# Lat: None, Long: None
#
# USER  18215247 tonysoares
# Tweet length:  250
# Polarity:  -0.11481481481481481
# Subjectivity:  0.5648148148148149
# Tweet content:  I wonder if @morningmika and @JoeNBC would turn down takin Hydroxychloroquine if caught COVID19 and facing near dea… https://t.co/LkQeKrU0k3
# Lat: None, Long: None
#
# USER  984976058444369920 VeriQuester
# Tweet length:  123
# Polarity:  0.0
# Subjectivity:  0.0
# Tweet content:  Strict fines in Australia!!!
#
# No warnings?
#
# #Covid_19 #COVID19 #coronavirus #coronavirusaustralia
#
# https://t.co/whcd2hm8kS
# Lat: None, Long: None
#
# USER  2172697775 belfastbarman
# Tweet length:  90
# Polarity:  0.0625
# Subjectivity:  0.23333333333333334
# Tweet content:  This last 6 months has been a wild ride for whoever in Dept Infra looks after MOT centres!
# Lat: None, Long: None
#
# USER  19065008 jakedimare
# Tweet length:  109
# Polarity:  -0.19999999999999998
# Subjectivity:  0.6333333333333333
# Tweet content:  'Deaths per hour' is now a relevant yet grim metric on the global impact of #COVID19. https://t.co/LjAs3MV4KC
# Lat: None, Long: None

# %%
if (connection.is_connected()):
    connection.close()
